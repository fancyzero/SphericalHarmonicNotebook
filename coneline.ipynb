# %%
import math
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from functools import partial
from collections import namedtuple
import numpy as np


fig,ax = plt.subplots(   subplot_kw=dict(projection='3d'))
fig.set_size_inches((10,10))
fig.tight_layout()
ax.grid(True)
ax.axis(True)

N = 20
ax.set_xlim3d(-1,N)
ax.set_ylim3d(-1,N)
ax.set_zlim3d(-1,N)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

xx=[]
yy=[]
zz=[]

def LightIntensity(p):
    i = 0
    for x in range(6):
        for y in range(6):
            i += np.linalg.norm(p-np.array((x,y,0)))

d = np.array((0,0,1))
o = [10,10,0]
for x in range(N):
    for y in range(N):
        for z in range(N):
            p = np.array((x,y,z))


            if ( True ):
                xx.append(x)
                yy.append(y)
                zz.append(z)
ax.scatter(xx,yy,zz)
